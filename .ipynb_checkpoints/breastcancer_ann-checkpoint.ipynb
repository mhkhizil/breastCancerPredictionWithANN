# %%
#This is the full code section and below this this full code is seperated into several code snippet where you can run each snippet to get more clarity and readability
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import plotly.offline as py
import plotly.graph_objs as go
import plotly.tools as tls
import plotly.figure_factory as ff
import warnings

# Suppress warnings
warnings.filterwarnings("ignore")

# Read data from CSV file
df = pd.read_csv('./breast-cancer-prediction/FNAdata.csv')

# Print data info
df

# Import libraries for visualization
import plotly.express as px
from plotly.offline import init_notebook_mode, iplot

# Configure plotly for notebook mode
init_notebook_mode(connected=True)

## Create pie chart to visualize diagnosis distribution (helps understand proportions of benign and malignant cases)
diagnosisPieChart = px.pie(df, values=df['diagnosis'].value_counts().values, names=df['diagnosis'].value_counts().index)
diagnosisPieChart.show()

# Calculate correlation matrix to identify potential feature dependencies
corr = df.iloc[:,2:].corr()

# Define colormap for heatmap (visual aid for interpreting correlations)
colormap = sns.diverging_palette(220, 30, as_cmap = True)

# Create heatmap to visualize feature correlations (helps identify redundant features)
plt.figure(figsize=(14,14))
sns.heatmap(corr, cbar = True,square = True,annot=True,fmt= '.2f',annot_kws={'size': 8},
            cmap = colormap, linewidths=0.1, linecolor='white')
#title of the heat map
plt.title('Correlation of df Features', y=1.05, size=15)

# Create correlation matrix (absolute values) for easier identification of high correlations
corr_matrix = df.iloc[:, 2:].corr().abs()

# Select upper triangle of correlation matrix (excluding diagonal) to avoid self-correlation
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

# Find features with correlation greater than 0.95 (highly correlated)
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]
print("Features to drop due to high correlation:", to_drop)

# Drop highly correlated features to avoid multicollinearity issues
df.drop(to_drop, axis=1, inplace=True)

# Print number of remaining features after dropping highly correlated ones
print("Number of features after dropping highly correlated ones:", len(df.columns))

# Check for missing values (important to address before training)
print(df.isnull().sum())  # View how many missing values each column has

# Drop unnecessary features (can be adjusted based on domain knowledge)
df.drop(['Unnamed: 32','id'],axis=1,inplace=True)

# Separate independent (features) and dependent (target) variables
x = df.drop('diagnosis',axis=1)
y = df.diagnosis

# Encode categorical target variable (necessary for ANN processing)
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
y = lb.fit_transform(y)

# Split data into training and testing sets for model evaluation

from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=40)

# Standardize features (optional, can be helpful for some algorithms)
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
xtrain = sc.fit_transform(xtrain)
xtest = sc.transform(xtest)


# Import Keras libraries for building the ANN model
import keras
from keras.models import Sequential
from keras.layers import Dense, LeakyReLU, PReLU, ELU, Dropout
from tensorflow.keras.layers import BatchNormalization

# Create a sequential artificial neural network (ANN) model
ann = Sequential()

# Add first hidden layer with 30 neurons and ReLU activation (common choice for hidden layers due to its non-linearity)
ann.add(Dense(units = 30,activation = 'relu'))
ann.add(BatchNormalization())  # Add batch normalization layer for regularization (improves generalization)
ann.add(Dropout(0.5)) # Add dropout layer to prevent overfitting (reduces model complexity)


# Add second hidden layer with 30 neurons and ReLU activation for better feature extraction
ann.add(Dense(units = 30,activation = 'relu'))
ann.add(BatchNormalization()) 
ann.add(Dropout(0.5))

# Add output layer with 1 neuron and sigmoid activation for binary classification
ann.add(Dense(units = 1,activation = 'sigmoid'))

# Compile the ANN using Adam optimizer (popular optimizer for various tasks), binary crossentropy loss (suitable for binary classification), and accuracy metric (measures overall correct predictions)
ann.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Implement early stopping to prevent overfitting (stops training when validation loss stops improving)
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)

# Train the ANN in batches of 32 with validation data and early stopping
model=ann.fit(xtrain, ytrain,batch_size = 32, validation_data=(xtest, ytest),epochs =100,callbacks = [early_stop])

# Print model summary to understand the architecture (number of layers, neurons)

ann.summary()

# Plot training and validation loss curves to visualize the learning process (helps identify underfitting or overfitting)
losses = pd.DataFrame(ann.history.history)
losses.plot()

# Make predictions on test data
y_pred = ann.predict(xtest)

# Convert predictions to binary labels (threshold at 0.5) based on sigmoid activation output
y_pred = (y_pred>0.5)

# Calculate evaluation metrics to assess model performance
from sklearn.metrics import confusion_matrix, accuracy_score

cm = confusion_matrix(ytest,y_pred)  # Confusion matrix visualizes true vs predicted classifications
score = accuracy_score(ytest,y_pred) # Accuracy measures overall correct predictions

print("Confusion Matrix:\n", cm)
print("Accuracy:", score)

# Print classification report for detailed performance breakdown (precision, recall, F1-score)
from sklearn.metrics import classification_report
print(classification_report(ytest,y_pred))

# Create heatmap of confusion matrix for better visualization of classification results
plt.figure(figsize=[14,7])
sns.heatmap(cm,annot=True)
plt.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.30.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# Features to drop due to high correlation: ['perimeter_mean', 'area_mean', 'perimeter_se', 'area_se', 'radius_worst', 'perimeter_worst', 'area_worst']
# Number of features after dropping highly correlated ones: 26
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# texture_worst                0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# symmetry_worst               0
# fractal_dimension_worst      0
# Unnamed: 32                569
# dtype: int64
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.4443 - loss: 1.1390 - val_accuracy: 0.5614 - val_loss: 0.6831
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5997 - loss: 0.8903 - val_accuracy: 0.7982 - val_loss: 0.5711
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6134 - loss: 0.7583 - val_accuracy: 0.9035 - val_loss: 0.4811
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6735 - loss: 0.6275 - val_accuracy: 0.9298 - val_loss: 0.4110
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6850 - loss: 0.5986 - val_accuracy: 0.9386 - val_loss: 0.3582
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8224 - loss: 0.4381 - val_accuracy: 0.9474 - val_loss: 0.3172
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7988 - loss: 0.4417 - val_accuracy: 0.9474 - val_loss: 0.2834
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8029 - loss: 0.4548 - val_accuracy: 0.9649 - val_loss: 0.2562
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8380 - loss: 0.3652 - val_accuracy: 0.9737 - val_loss: 0.2349
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8602 - loss: 0.3469 - val_accuracy: 0.9649 - val_loss: 0.2166
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8814 - loss: 0.3052 - val_accuracy: 0.9561 - val_loss: 0.2026
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8762 - loss: 0.3301 - val_accuracy: 0.9561 - val_loss: 0.1889
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.
100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9403 - loss: 0.1333 - val_accuracy: 0.9649 - val_loss: 0.0965
# Epoch 79/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9697 - loss: 0.0963 - val_accuracy: 0.9649 - val_loss: 0.0960
# Epoch 80/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9774 - loss: 0.0890 - val_accuracy: 0.9737 - val_loss: 0.0964
# Epoch 81/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9665 - loss: 0.1043 - val_accuracy: 0.9649 - val_loss: 0.0969
# Epoch 82/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9563 - loss: 0.1267 - val_accuracy: 0.9649 - val_loss: 0.0982
# Epoch 83/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9690 - loss: 0.0823 - val_accuracy: 0.9649 - val_loss: 0.0971
# Epoch 84/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9409 - loss: 0.1368 - val_accuracy: 0.9649 - val_loss: 0.0987
# Epoch 85/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9737 - loss: 0.0821 - val_accuracy: 0.9737 - val_loss: 0.0987
# Epoch 86/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9665 - loss: 0.1122 - val_accuracy: 0.9737 - val_loss: 0.0971
# Epoch 87/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9304 - loss: 0.1318 - val_accuracy: 0.9737 - val_loss: 0.0971
# Epoch 88/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9505 - loss: 0.0914 - val_accuracy: 0.9737 - val_loss: 0.0953
# Epoch 89/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9738 - loss: 0.0818 - val_accuracy: 0.9737 - val_loss: 0.0953
# Epoch 90/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9742 - loss: 0.0774 - val_accuracy: 0.9737 - val_loss: 0.0980
# Epoch 91/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9417 - loss: 0.1408 - val_accuracy: 0.9737 - val_loss: 0.0978
# Epoch 91: early stopping
# Model: "sequential_13"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_39 (Dense)                     │ (None, 30)                  │             720 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_24               │ (None, 30)                  │             120 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_26 (Dropout)                 │ (None, 30)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_40 (Dense)                     │ (None, 30)                  │             930 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_25               │ (None, 30)                  │             120 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_27 (Dropout)                 │ (None, 30)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_41 (Dense)                     │ (None, 1)                   │              31 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 5,525 (21.59 KB)
#  Trainable params: 1,801 (7.04 KB)
#  Non-trainable params: 120 (480.00 B)
#  Optimizer params: 3,604 (14.08 KB)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Confusion Matrix:
#  [[74  1]
#  [ 2 37]]
# Accuracy: 0.9736842105263158
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98        75
#            1       0.97      0.95      0.96        39
#
#     accuracy                           0.97       114
#    macro avg       0.97      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114

# %%
 # This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import plotly.offline as py
import plotly.graph_objs as go
import plotly.tools as tls
import plotly.figure_factory as ff
import warnings

# Suppress warnings
warnings.filterwarnings("ignore")

# Read data from CSV file
df = pd.read_csv('./breast-cancer-prediction/FNAdata.csv')

# Print data info
df #you can also use print(df) because if you are running this code on other platform only df would not show anything
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0    ...          17.33           184.60      2019.0           0.16220
# 1    ...          23.41           158.80      1956.0           0.12380
# 2    ...          25.53           152.50      1709.0           0.14440
# 3    ...          26.50            98.87       567.7           0.20980
# 4    ...          16.67           152.20      1575.0           0.13740
# ..   ...            ...              ...         ...               ...
# 564  ...          26.40           166.10      2027.0           0.14100
# 565  ...          38.25           155.00      1731.0           0.11660
# 566  ...          34.12           126.70      1124.0           0.11390
# 567  ...          39.42           184.60      1821.0           0.16500
# 568  ...          30.37            59.16       268.6           0.08996
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0              0.66560           0.7119                0.2654          0.4601
# 1              0.18660           0.2416                0.1860          0.2750
# 2              0.42450           0.4504                0.2430          0.3613
# 3              0.86630           0.6869                0.2575          0.6638
# 4              0.20500           0.4000                0.1625          0.2364
# ..                 ...              ...                   ...             ...
# 564            0.21130           0.4107                0.2216          0.2060
# 565            0.19220           0.3215                0.1628          0.2572
# 566            0.30940           0.3403                0.1418          0.2218
# 567            0.86810           0.9387                0.2650          0.4087
# 568            0.06444           0.0000                0.0000          0.2871
#
#      fractal_dimension_worst  Unnamed: 32
# 0                    0.11890          NaN
# 1                    0.08902          NaN
# 2                    0.08758          NaN
# 3                    0.17300          NaN
# 4                    0.07678          NaN
# ..                       ...          ...
# 564                  0.07115          NaN
# 565                  0.06637          NaN
# 566                  0.07820          NaN
# 567                  0.12400          NaN
# 568                  0.07039          NaN
#
# [569 rows x 33 columns]

# %%
df.info #showing detailed info if there is no ouptu while you are running please add print()
# Out:
# <bound method DataFrame.info of            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0    ...          17.33           184.60      2019.0           0.16220
# 1    ...          23.41           158.80      1956.0           0.12380
# 2    ...          25.53           152.50      1709.0           0.14440
# 3    ...          26.50            98.87       567.7           0.20980
# 4    ...          16.67           152.20      1575.0           0.13740
# ..   ...            ...              ...         ...               ...
# 564  ...          26.40           166.10      2027.0           0.14100
# 565  ...          38.25           155.00      1731.0           0.11660
# 566  ...          34.12           126.70      1124.0           0.11390
# 567  ...          39.42           184.60      1821.0           0.16500
# 568  ...          30.37            59.16       268.6           0.08996
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0              0.66560           0.7119                0.2654          0.4601
# 1              0.18660           0.2416                0.1860          0.2750
# 2              0.42450           0.4504                0.2430          0.3613
# 3              0.86630           0.6869                0.2575          0.6638
# 4              0.20500           0.4000                0.1625          0.2364
# ..                 ...              ...                   ...             ...
# 564            0.21130           0.4107                0.2216          0.2060
# 565            0.19220           0.3215                0.1628          0.2572
# 566            0.30940           0.3403                0.1418          0.2218
# 567            0.86810           0.9387                0.2650          0.4087
# 568            0.06444           0.0000                0.0000          0.2871
#
#      fractal_dimension_worst  Unnamed: 32
# 0                    0.11890          NaN
# 1                    0.08902          NaN
# 2                    0.08758          NaN
# 3                    0.17300          NaN
# 4                    0.07678          NaN
# ..                       ...          ...
# 564                  0.07115          NaN
# 565                  0.06637          NaN
# 566                  0.07820          NaN
# 567                  0.12400          NaN
# 568                  0.07039          NaN
#
# [569 rows x 33 columns]>

# %%
# Import libraries for visualization
import plotly.express as px
from plotly.offline import init_notebook_mode, iplot

# Configure plotly for notebook mode
init_notebook_mode(connected=True)

# Create pie chart to visualize diagnosis distribution (helps understand proportions of benign and malignant cases)
diagnosisPieChart = px.pie(df, values=df['diagnosis'].value_counts().values, names=df['diagnosis'].value_counts().index)
diagnosisPieChart.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.30.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Calculate correlation matrix to identify potential feature dependencies
corr = df.iloc[:,2:].corr()

# Define colormap for heatmap (visual aid for interpreting correlations)
colormap = sns.diverging_palette(220, 30, as_cmap = True)

# Create heatmap to visualize feature correlations (helps identify redundant features)
plt.figure(figsize=(14,14))
sns.heatmap(corr, cbar = True,square = True,annot=True,fmt= '.2f',annot_kws={'size': 8},
            cmap = colormap, linewidths=0.1, linecolor='white')
#title of the heat map
plt.title('Correlation of df Features', y=1.05, size=15)
# Out:
# Text(0.5, 1.05, 'Correlation of df Features')

# %%
import numpy as np

# Create correlation matrix (absolute values) for easier identification of high correlations
corr_matrix = df.iloc[:, 2:].corr().abs()

# Select upper triangle of correlation matrix (excluding diagonal) to avoid self-correlation
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

# Find features with correlation greater than 0.95 (highly correlated)
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]
print("Features to drop due to high correlation:", to_drop)

# Drop highly correlated features to avoid multicollinearity issues
df.drop(to_drop, axis=1, inplace=True)
# Out:
# Features to drop due to high correlation: ['perimeter_mean', 'area_mean', 'perimeter_se', 'area_se', 'radius_worst', 'perimeter_worst', 'area_worst']

# %%
# Print number of remaining features after dropping highly correlated ones
print("Number of features after dropping highly correlated ones:", len(df.columns))
# Out:
# Number of features after dropping highly correlated ones: 26

# %%
# Check for missing values (important to address before training)
print(df.isnull().sum())  # View how many missing values each column has
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# texture_worst                0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# symmetry_worst               0
# fractal_dimension_worst      0
# Unnamed: 32                569
# dtype: int64

# %%
# Drop unnecessary features 
df.drop(['Unnamed: 32','id'],axis=1,inplace=True)

# %%
# Separate independent (features) and dependent (target) variables
#indepeendent variables
x = df.drop('diagnosis',axis=1)
#dependent variables
y = df.diagnosis

# %%
# Encode categorical target variable (necessary for ANN processing)
from sklearn.preprocessing import LabelEncoder
#creating the object
label = LabelEncoder()
y = label.fit_transform(y)

# %%
# Split data into training and testing sets for model evaluation

from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=40)

# %%
# Standardize features 
from sklearn.preprocessing import StandardScaler
#creating object
scaler = StandardScaler()
xtrain = scaler.fit_transform(xtrain)
xtest = scaler.transform(xtest)

# %%
# Import Keras libraries for building the ANN model
import keras
#import sequential module
from keras.models import Sequential
#import dense module for hidden layers and actiavtion functions
from keras.layers import Dense, LeakyReLU, PReLU, ELU, Dropout
from tensorflow.keras.layers import BatchNormalization

# %%
# Create a sequential artificial neural network (ANN) model
ann = Sequential()

# Add first hidden layer with 30 neurons and ReLU activation (common choice for hidden layers due to its non-linearity)
ann.add(Dense(units = 30,activation = 'relu'))
ann.add(BatchNormalization())   # Add batch normalization layer for regularization (improves generalization)
ann.add(Dropout(0.5))  # Add dropout layer to prevent overfitting (reduces model complexity)

# Add second hidden layer with 30 neurons and ReLU activation for better feature extraction
ann.add(Dense(units = 30,activation = 'relu'))
ann.add(BatchNormalization())
ann.add(Dropout(0.5))

# Add output layer with 1 neuron and sigmoid activation for binary classification
ann.add(Dense(units = 1,activation = 'sigmoid'))

# %%
# Compile the ANN using Adam optimizer (popular optimizer for various tasks), binary crossentropy loss (suitable for binary classification), and accuracy metric (measures overall correct predictions)
ann.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Implement early stopping to prevent overfitting (stops training when validation loss stops improving)
#seting callback for monitoring maximumaccuracy
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)

# Train the ANN in batches of 32(This ia a natch learning) with validation data and early stopping
model=ann.fit(xtrain, ytrain,batch_size = 32, validation_data=(xtest, ytest),epochs =100,callbacks = [early_stop])
# Out:
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.4080 - loss: 1.1980 - val_accuracy: 0.6579 - val_loss: 0.7493
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5138 - loss: 0.9002 - val_accuracy: 0.6842 - val_loss: 0.6240
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5759 - loss: 0.7310 - val_accuracy: 0.8158 - val_loss: 0.5276
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7075 - loss: 0.5936 - val_accuracy: 0.8509 - val_loss: 0.4605
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7439 - loss: 0.5069 - val_accuracy: 0.8684 - val_loss: 0.4032
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7558 - loss: 0.4723 - val_accuracy: 0.9211 - val_loss: 0.3521
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8150 - loss: 0.4377 - val_accuracy: 0.9298 - val_loss: 0.3102
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8264 - loss: 0.3907 - val_accuracy: 0.9386 - val_loss: 0.2769
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8142 - loss: 0.4022 - val_accuracy: 0.9474 - val_loss: 0.2517
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8711 - loss: 0.3319 - val_accuracy: 0.9561 - val_loss: 0.2327
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8425 - loss: 0.3961 - val_accuracy: 0.9561 - val_loss: 0.2163
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8870 - loss: 0.2824 - val_accuracy: 0.9649 - val_loss: 0.2024
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8728 - loss: 0.2848 - val_accuracy: 0.9649 - val_loss: 0.1895
# Epoch 14/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8942 - loss: 0.2954 - val_accuracy: 0.9649 - val_loss: 0.1812
# Epoch 15/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8928 - loss: 0.2797 - val_accuracy: 0.9649 - val_loss: 0.1757
# Epoch 16/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9090 - loss: 0.2560 - val_accuracy: 0.9649 - val_loss: 0.1712
# Epoch 17/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8874 - loss: 0.2583 - val_accuracy: 0.9649 - val_loss: 0.1630
# Epoch 18/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8982 - loss: 0.2437 - val_accuracy: 0.9649 - val_loss: 0.1572
# Epoch 19/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8979 - loss: 0.2160 - val_accuracy: 0.9649 - val_loss: 0.1508
# Epoch 20/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9107 - loss: 0.2243 - val_accuracy: 0.9737 - val_loss: 0.1474
# Epoch 21/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.
100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9456 - loss: 0.1709 - val_accuracy: 0.9649 - val_loss: 0.1212
# Epoch 87/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9645 - loss: 0.1101 - val_accuracy: 0.9649 - val_loss: 0.1223
# Epoch 88/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9756 - loss: 0.0666 - val_accuracy: 0.9649 - val_loss: 0.1215
# Epoch 89/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9475 - loss: 0.1273 - val_accuracy: 0.9649 - val_loss: 0.1196
# Epoch 90/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9637 - loss: 0.0937 - val_accuracy: 0.9649 - val_loss: 0.1228
# Epoch 91/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9689 - loss: 0.0811 - val_accuracy: 0.9649 - val_loss: 0.1214
# Epoch 92/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9783 - loss: 0.0696 - val_accuracy: 0.9649 - val_loss: 0.1190
# Epoch 93/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9644 - loss: 0.1045 - val_accuracy: 0.9649 - val_loss: 0.1216
# Epoch 94/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9463 - loss: 0.0998 - val_accuracy: 0.9649 - val_loss: 0.1237
# Epoch 95/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9693 - loss: 0.0738 - val_accuracy: 0.9649 - val_loss: 0.1180
# Epoch 96/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9574 - loss: 0.1085 - val_accuracy: 0.9649 - val_loss: 0.1233
# Epoch 97/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9705 - loss: 0.0687 - val_accuracy: 0.9649 - val_loss: 0.1253
# Epoch 98/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9526 - loss: 0.1143 - val_accuracy: 0.9649 - val_loss: 0.1207
# Epoch 99/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9787 - loss: 0.0811 - val_accuracy: 0.9649 - val_loss: 0.1182
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9531 - loss: 0.1157 - val_accuracy: 0.9649 - val_loss: 0.1198

# %%
# Print model summary to understand the architecture (number of layers, neurons)

ann.summary()
# Out:
# Model: "sequential_14"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_42 (Dense)                     │ (None, 30)                  │             720 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_26               │ (None, 30)                  │             120 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_28 (Dropout)                 │ (None, 30)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_43 (Dense)                     │ (None, 30)                  │             930 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_27               │ (None, 30)                  │             120 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_29 (Dropout)                 │ (None, 30)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_44 (Dense)                     │ (None, 1)                   │              31 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 5,525 (21.59 KB)
#  Trainable params: 1,801 (7.04 KB)
#  Non-trainable params: 120 (480.00 B)
#  Optimizer params: 3,604 (14.08 KB)

# %%
# Plot training and validation loss curves to visualize the learning process (helps identify underfitting or overfitting)
losses = pd.DataFrame(ann.history.history)
losses.plot()
# Out:
# <Axes: >

# %%
# Make predictions on test data
y_pred = ann.predict(xtest)

# Convert predictions to binary labels (threshold at 0.5) based on sigmoid activation output
y_pred = (y_pred>0.5)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step

# %%
# Calculate evaluation metrics to assess model performance
from sklearn.metrics import confusion_matrix, accuracy_score

cm = confusion_matrix(ytest,y_pred)  # Confusion matrix visualizes true vs predicted classifications
score = accuracy_score(ytest,y_pred) # Accuracy measures overall correct predictions

print("Confusion Matrix:\n", cm)
print("Accuracy score:", score)
# Out:
# Confusion Matrix:
#  [[73  2]
#  [ 2 37]]
# Accuracy score: 0.9649122807017544

# %%
# Print classification report for detailed performance breakdown (precision, recall, F1-score)
from sklearn.metrics import classification_report
print(classification_report(ytest,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97        75
#            1       0.95      0.95      0.95        39
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.96      0.96       114
# weighted avg       0.96      0.96      0.96       114

# %%
# Create heatmap of confusion matrix for better visualization of classification results
plt.figure(figsize=[14,7])
sns.heatmap(cm,annot=True)
plt.show()
